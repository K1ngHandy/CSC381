# %%
import pandas as pd
import numpy as np
from pathlib import Path

pd.set_option('display.width', 120)
pd.set_option('display.max_columns', 20)

print('pandas', pd.__version__)
# Out:
# pandas 3.0.5

# %%
RAW = Path('../raw/philly_rentals_raw-update.csv')

if not RAW.exists():
    RAW = Path('philly_rentals_raw-update.csv')

raw = pd.read_csv(RAW)
df = raw.copy()

print(RAW.resolve())
print(df.shape)
# Out:
# /Users/k1nghandy/git/learning/wcupa/CSC381-01/CSC381/hw/hw-1/raw/philly_rentals_raw-update.csv
# (31, 6)

# %%
def rows_changed(before, after, what):
    lost = before - after
    pct = 100 * lost / before if before else 0
    print(f'{what}: {before} -> {after} rows ({lost} removed, {pct:.1f}%)')
    return after

# %%
df.head(10)
# Out:
#   listing_id        neighborhood bedrooms  bathrooms    sqft       rent
# 0     R-2001            Fishtown        1        1.0   620.0  $1,450.00
# 1     R-2002            Manayunk        2        1.0   890.0       1750
# 2     R-2003     University City        1        1.0   540.0  $1,395.00
# 3     R-2004            fishtown        2        1.0   845.0      1,900
# 4     R-2005  Northern Liberties        3        2.0  1240.0  $2,750.00
# 5     R-2006            Old City        1        1.0   600.0       1650
# 6     R-2007            Manayunk      NaN        1.0   710.0  $1,525.00
# 7     R-2008            FISHTOWN        2        1.5   930.0      2,050
# 8     R-2009     University City        1        1.0   820.0  $1,875.00
# 9     R-2010            Old City        2        2.0   980.0       2400

# %%
df.tail(3)
# Out:
#    listing_id     neighborhood bedrooms  bathrooms     sqft        rent
# 28     R-2029  University City        2        1.5    835.0   $1,990.00
# 29     R-2030         Old City        3        2.0   1265.0       2,850
# 30      TOTAL              NaN      NaN        NaN  26385.0  $54,395.00

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   listing_id    30 non-null     str
#  1   neighborhood  29 non-null     str
#  2   bedrooms      27 non-null     str
#  3   bathrooms     29 non-null     float64
#  4   sqft          30 non-null     float64
#  5   rent          30 non-null     str
# dtypes: float64(2), str(4)
# memory usage: 1.6 KB

# %%
df['neighborhood'].value_counts()
# Out:
# neighborhood
# Manayunk              6
# University City       6
# Northern Liberties    5
# Old City              5
# Fishtown              3
# fishtown              2
# FISHTOWN              1
# Fishtown              1
# Name: count, dtype: int64

# %% [markdown]
# *Part 1 — what is wrong with this file*
#
# 1. 6 — 'bedrooms' R-2007 is missing bedroom data.
# 2. Sqft in tail is a total rather than average.
# 3. Rent amounts have comma divider and $ in some, but not all.
# 4. Neighborhood case is not matching – some lowercase, some Uppercase, some all capital.
